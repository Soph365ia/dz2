# %% [markdown]
# # Задание:
# #
# # Продолжить логику битв армий жуков
# # Где каждая армия бьёт другую по очереди
# # пока у неё не закончатся жуки
# #
# # Жук умирает при здоровье <= 0
# # Жук получает +10 хп за убийство жука, но не больше своего max_hp в армии
# #
# # Весь прогресс битвы можно красиво выводить с помощью rich
# #
# # Должен быть функционал сравнения армий
# #
# # Все данные о битве (сколько армий и под каким именем) - запрашивайте у пользователя
# # Урон должен быть определен так же как и ХП, но при .attack() варьироваться каждый раз от рандома

# %%
import random
from enum import StrEnum
from typing import Self

class Names(StrEnum):
    JOHN = "Джон Леннон"
    PAUL = "Пол Маккартни" 
    GEORGE = "Джордж Харрисон"
    RINGO = "Ринго Старр"

class Beetle:
    health_points: int
    name: Names

    def __init__(self, health_points: int = 100, name: Names = Names.JOHN) -> None:
        self.health_points = health_points
        self.name = name

    def __eq__(self, other: Self) -> bool:
        return self.health_points == other.health_points

    def __lt__(self, other: Self) -> bool:
        return self.health_points < other.health_points

    def __le__(self, other: Self) -> bool:
        return self.health_points <= other.health_points

    def __str__(self) -> str:
        return f'жук(name="{self.name}", hp={self.health_points})'

    def styling(self) -> str:
        if self.name is Names.JOHN:
            return "в стиле Джонни"
        elif self.name is Names.PAUL:
            return "в стиле Маккартни"
        return "без стиля"

    def attack(self, other: Self) -> int:
        damage = random.randint(5, 15)
        print(f"{self.name} атакует {other.name} {self.styling()} и наносит {damage} урона")
        other.health_points -= damage
        return damage

class BeetlesArmy:
    beetles_list: list[Beetle]
    beetles_name: Names
    beetles_max_health_points: int

    def __init__(self, beetles_name: Names, beetles_army_size: int = 20, beetles_max_health_points: int = 100):
        self.beetles_list = []
        self.beetles_name = beetles_name
        self.beetles_max_health_points = beetles_max_health_points

        for _ in range(beetles_army_size):
            beetle = Beetle(
                health_points=random.randint(1, self.beetles_max_health_points),
                name=self.beetles_name,
            )
            self.beetles_list.append(beetle)

    def __len__(self) -> int:
        return len(self.beetles_list)

    def __add__(self, other: Self) -> Self:
        if self.beetles_name != other.beetles_name:
            raise ValueError("ты че")
        new_army = BeetlesArmy(beetles_army_size=1, beetles_name=self.beetles_name)
        new_army.beetles_list = self.beetles_list + other.beetles_list
        return new_army

    def __gt__(self, other: Self) -> bool:
        return len(self) > len(other)

    def print_army_listing(self):
        for beetle in self.beetles_list:
            print(beetle)

    def is_alive(self) -> bool:
        return len(self.beetles_list) > 0

    def remove_dead(self):
        self.beetles_list = [beetle for beetle in self.beetles_list if beetle.health_points > 0]

    def attack_army(self, other: Self):
        if not self.beetles_list or not other.beetles_list:
            return

        attacker = random.choice(self.beetles_list)
        defender = random.choice(other.beetles_list)
        
        damage = attacker.attack(defender)
        
        if defender.health_points <= 0:
            print(f"{defender.name} был уничтожен тапком")
            attacker.health_points = min(attacker.health_points + 10, self.beetles_max_health_points)
            print(f"{attacker.name} получает +10 хп. теперь имеет {attacker.health_points} хп")
        
        other.remove_dead()

def main():
    print("Битва начинается")
    
    name1 = input("Введите имя первой армии (JOHN/PAUL/GEORGE/RINGO): ").upper()
    size1 = int(input("Введите размер первой армии: "))
    hp1 = int(input("Введите максимальное хп первой армии: "))
    
    name2 = input("Введите имя второй армии (JOHN/PAUL/GEORGE/RINGO): ").upper()
    size2 = int(input("Введите размер второй армии: "))
    hp2 = int(input("Введите максимальное хп второй армии: "))
    
    army1 = BeetlesArmy(Names[name1], size1, hp1)
    army2 = BeetlesArmy(Names[name2], size2, hp2)
    
    print(f"\n битва: {army1.beetles_name} против {army2.beetles_name}")
    print(f"армия 1: {len(army1)} жуков")
    print(f"армия 2: {len(army2)} жуков")
    
    round_num = 1
    
    while army1.is_alive() and army2.is_alive():
        print(f"раунд {round_num}")
        
        army1.attack_army(army2)
        if not army2.is_alive():
            break
            
        army2.attack_army(army1)
        
        print(f"после раунда {round_num}:")
        print(f"армия 1: осталось {len(army1)} жуков")
        print(f"армия 2: осталось {len(army2)} жуков")
        
        round_num += 1
    
    print(f"финал битвы ")
    if army1.is_alive():
        print(f"{army1.beetles_name} победили вау!")
    else:
        print(f"{army2.beetles_name} победили вау!")
    
    if army1 > army2:
        print(f"У {army1.beetles_name} больше жуков")
    elif army2 > army1:
        print(f"У {army2.beetles_name} больше жуков")
    else:
        print("У супер армий одинаковое количество жуков")

if __name__ == "__main__":
    main()
# Out:
# Битва начинается
#  битва: Пол Маккартни против Ринго Старр
# армия 1: 73 жуков
# армия 2: 56 жуков
# раунд 1
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 1:
# армия 1: осталось 73 жуков
# армия 2: осталось 56 жуков
# раунд 2
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 2:
# армия 1: осталось 73 жуков
# армия 2: осталось 56 жуков
# раунд 3
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 3:
# армия 1: осталось 72 жуков
# армия 2: осталось 56 жуков
# раунд 4
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 4:
# армия 1: осталось 72 жуков
# армия 2: осталось 56 жуков
# раунд 5
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 5:
# армия 1: осталось 72 жуков
# армия 2: осталось 55 жуков
# раунд 6
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 6:
# армия 1: осталось 72 жуков
# армия 2: осталось 55 жуков
# раунд 7
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 7:
# армия 1: осталось 72 жуков
# армия 2: осталось 54 жуков
# раунд 8
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 13 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 8:
# армия 1: осталось 72 жуков
# армия 2: осталось 53 жуков
# раунд 9
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 9:
# армия 1: осталось 72 жуков
# армия 2: осталось 52 жуков
# раунд 10
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 10:
# армия 1: осталось 71 жуков
# армия 2: осталось 51 жуков
# раунд 11
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 11:
# армия 1: осталось 71 жуков
# армия 2: осталось 51 жуков
# раунд 12
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 12:
# армия 1: осталось 71 жуков
# армия 2: осталось 51 жуков
# раунд 13
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 25 хп
# после раунда 13:
# армия 1: осталось 70 жуков
# армия 2: осталось 51 жуков
# раунд 14
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 14:
# армия 1: осталось 70 жуков
# армия 2: осталось 51 жуков
# раунд 15
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 15:
# армия 1: осталось 70 жуков
# армия 2: осталось 50 жуков
# раунд 16
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 16:
# армия 1: осталось 70 жуков
# армия 2: осталось 50 жуков
# раунд 17
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 17:
# армия 1: осталось 70 жуков
# армия 2: осталось 50 жуков
# раунд 18
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 30 хп
# после раунда 18:
# армия 1: осталось 69 жуков
# армия 2: осталось 50 жуков
# раунд 19
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 11 хп
# после раунда 19:
# армия 1: осталось 68 жуков
# армия 2: осталось 50 жуков
# раунд 20
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 20:
# армия 1: осталось 68 жуков
# армия 2: осталось 50 жуков
# раунд 21
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 21:
# армия 1: осталось 68 жуков
# армия 2: осталось 50 жуков
# раунд 22
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 14 хп
# после раунда 22:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 23
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 23:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 24
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 24:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 25
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 25:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 26
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 26:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 27
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 27:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 28
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 28:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 29
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 29:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 30
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 30:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 31
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 31:
# армия 1: осталось 67 жуков
# армия 2: осталось 50 жуков
# раунд 32
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 32:
# армия 1: осталось 67 жуков
# армия 2: осталось 49 жуков
# раунд 33
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 33:
# армия 1: осталось 66 жуков
# армия 2: осталось 49 жуков
# раунд 34
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 34:
# армия 1: осталось 66 жуков
# армия 2: осталось 48 жуков
# раунд 35
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 35:
# армия 1: осталось 65 жуков
# армия 2: осталось 48 жуков
# раунд 36
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 12 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 36:
# армия 1: осталось 65 жуков
# армия 2: осталось 47 жуков
# раунд 37
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 12 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 37:
# армия 1: осталось 65 жуков
# армия 2: осталось 46 жуков
# раунд 38
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 38:
# армия 1: осталось 65 жуков
# армия 2: осталось 45 жуков
# раунд 39
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 39:
# армия 1: осталось 65 жуков
# армия 2: осталось 45 жуков
# раунд 40
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 40:
# армия 1: осталось 65 жуков
# армия 2: осталось 45 жуков
# раунд 41
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 41:
# армия 1: осталось 65 жуков
# армия 2: осталось 45 жуков
# раунд 42
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 42:
# армия 1: осталось 65 жуков
# армия 2: осталось 45 жуков
# раунд 43
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# после раунда 43:
# армия 1: осталось 65 жуков
# армия 2: осталось 44 жуков
# раунд 44
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 19 хп
# после раунда 44:
# армия 1: осталось 64 жуков
# армия 2: осталось 44 жуков
# раунд 45
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 11 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 19 хп
# после раунда 45:
# армия 1: осталось 63 жуков
# армия 2: осталось 43 жуков
# раунд 46
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 13 хп
# после раунда 46:
# армия 1: осталось 62 жуков
# армия 2: осталось 43 жуков
# раунд 47
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 47:
# армия 1: осталось 62 жуков
# армия 2: осталось 43 жуков
# раунд 48
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 19 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 48:
# армия 1: осталось 62 жуков
# армия 2: осталось 42 жуков
# раунд 49
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 24 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 49:
# армия 1: осталось 62 жуков
# армия 2: осталось 41 жуков
# раунд 50
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# после раунда 50:
# армия 1: осталось 62 жуков
# армия 2: осталось 41 жуков
# раунд 51
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 18 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 51:
# армия 1: осталось 62 жуков
# армия 2: осталось 40 жуков
# раунд 52
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 52:
# армия 1: осталось 62 жуков
# армия 2: осталось 40 жуков
# раунд 53
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 53:
# армия 1: осталось 62 жуков
# армия 2: осталось 40 жуков
# раунд 54
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 34 хп
# после раунда 54:
# армия 1: осталось 61 жуков
# армия 2: осталось 40 жуков
# раунд 55
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 22 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 55:
# армия 1: осталось 61 жуков
# армия 2: осталось 39 жуков
# раунд 56
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 56:
# армия 1: осталось 61 жуков
# армия 2: осталось 39 жуков
# раунд 57
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 57:
# армия 1: осталось 61 жуков
# армия 2: осталось 39 жуков
# раунд 58
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 58:
# армия 1: осталось 61 жуков
# армия 2: осталось 38 жуков
# раунд 59
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 24 хп
# после раунда 59:
# армия 1: осталось 60 жуков
# армия 2: осталось 37 жуков
# раунд 60
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 60:
# армия 1: осталось 60 жуков
# армия 2: осталось 37 жуков
# раунд 61
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 17 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# после раунда 61:
# армия 1: осталось 60 жуков
# армия 2: осталось 36 жуков
# раунд 62
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 62:
# армия 1: осталось 60 жуков
# армия 2: осталось 35 жуков
# раунд 63
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 63:
# армия 1: осталось 60 жуков
# армия 2: осталось 35 жуков
# раунд 64
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 64:
# армия 1: осталось 59 жуков
# армия 2: осталось 35 жуков
# раунд 65
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 14 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 24 хп
# после раунда 65:
# армия 1: осталось 58 жуков
# армия 2: осталось 34 жуков
# раунд 66
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 22 хп
# после раунда 66:
# армия 1: осталось 57 жуков
# армия 2: осталось 34 жуков
# раунд 67
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 67:
# армия 1: осталось 57 жуков
# армия 2: осталось 34 жуков
# раунд 68
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 68:
# армия 1: осталось 57 жуков
# армия 2: осталось 34 жуков
# раунд 69
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 69:
# армия 1: осталось 57 жуков
# армия 2: осталось 34 жуков
# раунд 70
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 34 хп
# после раунда 70:
# армия 1: осталось 56 жуков
# армия 2: осталось 34 жуков
# раунд 71
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 13 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 71:
# армия 1: осталось 56 жуков
# армия 2: осталось 33 жуков
# раунд 72
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 18 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 72:
# армия 1: осталось 56 жуков
# армия 2: осталось 32 жуков
# раунд 73
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 11 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 73:
# армия 1: осталось 56 жуков
# армия 2: осталось 31 жуков
# раунд 74
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 19 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 34 хп
# после раунда 74:
# армия 1: осталось 55 жуков
# армия 2: осталось 30 жуков
# раунд 75
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 24 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 23 хп
# после раунда 75:
# армия 1: осталось 54 жуков
# армия 2: осталось 29 жуков
# раунд 76
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 38 хп
# после раунда 76:
# армия 1: осталось 53 жуков
# армия 2: осталось 29 жуков
# раунд 77
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 77:
# армия 1: осталось 52 жуков
# армия 2: осталось 29 жуков
# раунд 78
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 78:
# армия 1: осталось 52 жуков
# армия 2: осталось 29 жуков
# раунд 79
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 79:
# армия 1: осталось 51 жуков
# армия 2: осталось 29 жуков
# раунд 80
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 80:
# армия 1: осталось 51 жуков
# армия 2: осталось 28 жуков
# раунд 81
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 81:
# армия 1: осталось 51 жуков
# армия 2: осталось 28 жуков
# раунд 82
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 16 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# после раунда 82:
# армия 1: осталось 51 жуков
# армия 2: осталось 27 жуков
# раунд 83
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 19 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 83:
# армия 1: осталось 51 жуков
# армия 2: осталось 26 жуков
# раунд 84
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 84:
# армия 1: осталось 51 жуков
# армия 2: осталось 26 жуков
# раунд 85
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# после раунда 85:
# армия 1: осталось 51 жуков
# армия 2: осталось 26 жуков
# раунд 86
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 86:
# армия 1: осталось 51 жуков
# армия 2: осталось 26 жуков
# раунд 87
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 28 хп
# после раунда 87:
# армия 1: осталось 50 жуков
# армия 2: осталось 26 жуков
# раунд 88
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 12 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 38 хп
# после раунда 88:
# армия 1: осталось 49 жуков
# армия 2: осталось 25 жуков
# раунд 89
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 89:
# армия 1: осталось 49 жуков
# армия 2: осталось 25 жуков
# раунд 90
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 23 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 90:
# армия 1: осталось 49 жуков
# армия 2: осталось 24 жуков
# раунд 91
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 40 хп
# после раунда 91:
# армия 1: осталось 48 жуков
# армия 2: осталось 24 жуков
# раунд 92
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 92:
# армия 1: осталось 48 жуков
# армия 2: осталось 24 жуков
# раунд 93
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 93:
# армия 1: осталось 48 жуков
# армия 2: осталось 24 жуков
# раунд 94
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 94:
# армия 1: осталось 48 жуков
# армия 2: осталось 24 жуков
# раунд 95
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 13 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 95:
# армия 1: осталось 48 жуков
# армия 2: осталось 23 жуков
# раунд 96
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 32 хп
# после раунда 96:
# армия 1: осталось 47 жуков
# армия 2: осталось 23 жуков
# раунд 97
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 97:
# армия 1: осталось 47 жуков
# армия 2: осталось 23 жуков
# раунд 98
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 98:
# армия 1: осталось 46 жуков
# армия 2: осталось 22 жуков
# раунд 99
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 99:
# армия 1: осталось 46 жуков
# армия 2: осталось 22 жуков
# раунд 100
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 13 хп
# после раунда 100:
# армия 1: осталось 45 жуков
# армия 2: осталось 22 жуков
# раунд 101
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 101:
# армия 1: осталось 44 жуков
# армия 2: осталось 22 жуков
# раунд 102
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 102:
# армия 1: осталось 43 жуков
# армия 2: осталось 22 жуков
# раунд 103
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 103:
# армия 1: осталось 43 жуков
# армия 2: осталось 21 жуков
# раунд 104
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 34 хп
# после раунда 104:
# армия 1: осталось 42 жуков
# армия 2: осталось 21 жуков
# раунд 105
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 105:
# армия 1: осталось 42 жуков
# армия 2: осталось 21 жуков
# раунд 106
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 106:
# армия 1: осталось 41 жуков
# армия 2: осталось 21 жуков
# раунд 107
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 13 хп
# после раунда 107:
# армия 1: осталось 40 жуков
# армия 2: осталось 21 жуков
# раунд 108
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 15 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 108:
# армия 1: осталось 40 жуков
# армия 2: осталось 20 жуков
# раунд 109
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 33 хп
# после раунда 109:
# армия 1: осталось 39 жуков
# армия 2: осталось 20 жуков
# раунд 110
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 110:
# армия 1: осталось 39 жуков
# армия 2: осталось 20 жуков
# раунд 111
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 23 хп
# после раунда 111:
# армия 1: осталось 38 жуков
# армия 2: осталось 20 жуков
# раунд 112
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 16 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 112:
# армия 1: осталось 38 жуков
# армия 2: осталось 19 жуков
# раунд 113
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 113:
# армия 1: осталось 38 жуков
# армия 2: осталось 19 жуков
# раунд 114
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 114:
# армия 1: осталось 38 жуков
# армия 2: осталось 19 жуков
# раунд 115
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 115:
# армия 1: осталось 37 жуков
# армия 2: осталось 19 жуков
# раунд 116
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 116:
# армия 1: осталось 37 жуков
# армия 2: осталось 19 жуков
# раунд 117
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 21 хп
# после раунда 117:
# армия 1: осталось 36 жуков
# армия 2: осталось 19 жуков
# раунд 118
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 23 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 37 хп
# после раунда 118:
# армия 1: осталось 35 жуков
# армия 2: осталось 18 жуков
# раунд 119
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 119:
# армия 1: осталось 35 жуков
# армия 2: осталось 18 жуков
# раунд 120
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 120:
# армия 1: осталось 35 жуков
# армия 2: осталось 18 жуков
# раунд 121
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 121:
# армия 1: осталось 35 жуков
# армия 2: осталось 18 жуков
# раунд 122
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 28 хп
# после раунда 122:
# армия 1: осталось 34 жуков
# армия 2: осталось 18 жуков
# раунд 123
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 123:
# армия 1: осталось 33 жуков
# армия 2: осталось 18 жуков
# раунд 124
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 124:
# армия 1: осталось 33 жуков
# армия 2: осталось 18 жуков
# раунд 125
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 25 хп
# после раунда 125:
# армия 1: осталось 32 жуков
# армия 2: осталось 18 жуков
# раунд 126
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 126:
# армия 1: осталось 31 жуков
# армия 2: осталось 18 жуков
# раунд 127
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 127:
# армия 1: осталось 31 жуков
# армия 2: осталось 18 жуков
# раунд 128
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 128:
# армия 1: осталось 30 жуков
# армия 2: осталось 17 жуков
# раунд 129
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# после раунда 129:
# армия 1: осталось 30 жуков
# армия 2: осталось 17 жуков
# раунд 130
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 11 хп
# после раунда 130:
# армия 1: осталось 29 жуков
# армия 2: осталось 17 жуков
# раунд 131
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 21 хп
# после раунда 131:
# армия 1: осталось 28 жуков
# армия 2: осталось 17 жуков
# раунд 132
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 132:
# армия 1: осталось 27 жуков
# армия 2: осталось 17 жуков
# раунд 133
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 133:
# армия 1: осталось 27 жуков
# армия 2: осталось 17 жуков
# раунд 134
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 16 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 134:
# армия 1: осталось 27 жуков
# армия 2: осталось 16 жуков
# раунд 135
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 135:
# армия 1: осталось 27 жуков
# армия 2: осталось 16 жуков
# раунд 136
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 21 хп
# после раунда 136:
# армия 1: осталось 26 жуков
# армия 2: осталось 16 жуков
# раунд 137
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 137:
# армия 1: осталось 26 жуков
# армия 2: осталось 16 жуков
# раунд 138
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 138:
# армия 1: осталось 25 жуков
# армия 2: осталось 16 жуков
# раунд 139
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 31 хп
# после раунда 139:
# армия 1: осталось 24 жуков
# армия 2: осталось 16 жуков
# раунд 140
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 23 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 140:
# армия 1: осталось 24 жуков
# армия 2: осталось 15 жуков
# раунд 141
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 141:
# армия 1: осталось 24 жуков
# армия 2: осталось 15 жуков
# раунд 142
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 25 хп
# после раунда 142:
# армия 1: осталось 23 жуков
# армия 2: осталось 15 жуков
# раунд 143
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 23 хп
# после раунда 143:
# армия 1: осталось 22 жуков
# армия 2: осталось 15 жуков
# раунд 144
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 144:
# армия 1: осталось 22 жуков
# армия 2: осталось 15 жуков
# раунд 145
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 21 хп
# после раунда 145:
# армия 1: осталось 21 жуков
# армия 2: осталось 15 жуков
# раунд 146
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 23 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 23 хп
# после раунда 146:
# армия 1: осталось 20 жуков
# армия 2: осталось 14 жуков
# раунд 147
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 31 хп
# после раунда 147:
# армия 1: осталось 19 жуков
# армия 2: осталось 14 жуков
# раунд 148
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 148:
# армия 1: осталось 19 жуков
# армия 2: осталось 14 жуков
# раунд 149
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# после раунда 149:
# армия 1: осталось 19 жуков
# армия 2: осталось 14 жуков
# раунд 150
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 32 хп
# после раунда 150:
# армия 1: осталось 18 жуков
# армия 2: осталось 14 жуков
# раунд 151
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 151:
# армия 1: осталось 17 жуков
# армия 2: осталось 14 жуков
# раунд 152
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 39 хп
# после раунда 152:
# армия 1: осталось 16 жуков
# армия 2: осталось 14 жуков
# раунд 153
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 153:
# армия 1: осталось 16 жуков
# армия 2: осталось 14 жуков
# раунд 154
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 17 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 19 хп
# после раунда 154:
# армия 1: осталось 15 жуков
# армия 2: осталось 13 жуков
# раунд 155
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# после раунда 155:
# армия 1: осталось 15 жуков
# армия 2: осталось 13 жуков
# раунд 156
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 156:
# армия 1: осталось 15 жуков
# армия 2: осталось 13 жуков
# раунд 157
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 17 хп
# после раунда 157:
# армия 1: осталось 14 жуков
# армия 2: осталось 13 жуков
# раунд 158
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 33 хп
# после раунда 158:
# армия 1: осталось 13 жуков
# армия 2: осталось 13 жуков
# раунд 159
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# после раунда 159:
# армия 1: осталось 13 жуков
# армия 2: осталось 13 жуков
# раунд 160
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 160:
# армия 1: осталось 13 жуков
# армия 2: осталось 12 жуков
# раунд 161
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 36 хп
# после раунда 161:
# армия 1: осталось 12 жуков
# армия 2: осталось 12 жуков
# раунд 162
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 162:
# армия 1: осталось 12 жуков
# армия 2: осталось 12 жуков
# раунд 163
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 41 хп
# после раунда 163:
# армия 1: осталось 11 жуков
# армия 2: осталось 12 жуков
# раунд 164
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 5 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 18 хп
# после раунда 164:
# армия 1: осталось 10 жуков
# армия 2: осталось 12 жуков
# раунд 165
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 25 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# после раунда 165:
# армия 1: осталось 10 жуков
# армия 2: осталось 11 жуков
# раунд 166
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 8 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 6 урона
# после раунда 166:
# армия 1: осталось 10 жуков
# армия 2: осталось 11 жуков
# раунд 167
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 40 хп
# после раунда 167:
# армия 1: осталось 9 жуков
# армия 2: осталось 11 жуков
# раунд 168
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 6 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# после раунда 168:
# армия 1: осталось 9 жуков
# армия 2: осталось 11 жуков
# раунд 169
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# после раунда 169:
# армия 1: осталось 9 жуков
# армия 2: осталось 11 жуков
# раунд 170
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 13 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 13 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# после раунда 170:
# армия 1: осталось 9 жуков
# армия 2: осталось 10 жуков
# раунд 171
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 12 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 18 хп
# после раунда 171:
# армия 1: осталось 8 жуков
# армия 2: осталось 10 жуков
# раунд 172
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 12 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 5 урона
# после раунда 172:
# армия 1: осталось 8 жуков
# армия 2: осталось 9 жуков
# раунд 173
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 9 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 26 хп
# после раунда 173:
# армия 1: осталось 7 жуков
# армия 2: осталось 9 жуков
# раунд 174
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 22 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 174:
# армия 1: осталось 7 жуков
# армия 2: осталось 8 жуков
# раунд 175
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр был уничтожен тапком
# Пол Маккартни получает +10 хп. теперь имеет 12 хп
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 21 хп
# после раунда 175:
# армия 1: осталось 6 жуков
# армия 2: осталось 7 жуков
# раунд 176
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 11 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# после раунда 176:
# армия 1: осталось 6 жуков
# армия 2: осталось 7 жуков
# раунд 177
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 15 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 11 урона
# после раунда 177:
# армия 1: осталось 6 жуков
# армия 2: осталось 7 жуков
# раунд 178
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 12 урона
# после раунда 178:
# армия 1: осталось 6 жуков
# армия 2: осталось 7 жуков
# раунд 179
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 10 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 13 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 29 хп
# после раунда 179:
# армия 1: осталось 5 жуков
# армия 2: осталось 7 жуков
# раунд 180
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 10 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 21 хп
# после раунда 180:
# армия 1: осталось 4 жуков
# армия 2: осталось 7 жуков
# раунд 181
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 7 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 15 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 23 хп
# после раунда 181:
# армия 1: осталось 3 жуков
# армия 2: осталось 7 жуков
# раунд 182
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 14 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 22 хп
# после раунда 182:
# армия 1: осталось 2 жуков
# армия 2: осталось 7 жуков
# раунд 183
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 9 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 7 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 31 хп
# после раунда 183:
# армия 1: осталось 1 жуков
# армия 2: осталось 7 жуков
# раунд 184
# Пол Маккартни атакует Ринго Старр в стиле Маккартни и наносит 14 урона
# Ринго Старр атакует Пол Маккартни без стиля и наносит 8 урона
# Пол Маккартни был уничтожен тапком
# Ринго Старр получает +10 хп. теперь имеет 24 хп
# после раунда 184:
# армия 1: осталось 0 жуков
# армия 2: осталось 7 жуков
# финал битвы
# Ринго Старр победили вау!
# У Ринго Старр больше жуков
